# %%
# %%bash
# # python3 -m venv venv # Create venv
# source venv/bin/activate # Activate virtual environment
# # pip install -r requirements.txt

# %%
# %cd code

# %%
# %%bash
# OMP_NUM_THREADS=4 MKL_NUM_THREADS=4 \
# python main.py --dataset amazon-book --model lgn --comment "lamb-amazon"\
#   --recdim 32 \
#   --layer 1 \
#   --epochs 10 \
#   --bpr_batch 4096 \
#   --tensorboard 1 \
#   --testbatch 512
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/amazon-book]
# 2380730 interactions for training
# 603378 interactions for testing
# amazon-book Sparsity : 0.0006188468344849981
# amazon-book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 4096,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 32,
#  'lightGCN_n_layers': 1,
#  'lr': 0.001,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 512}
# cores for test: 4
# comment: lamb-amazon
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# /Users/moonyj/repos/25-fall-recommender/code/dataloader.py:332: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:653.)
#   return torch.sparse.FloatTensor(index, data, torch.Size(coo.shape))
# don't split the matrix
# lgn is already to go(dropout:0)
# load and save to /Users/moonyj/repos/25-fall-recommender/code/checkpoints/lgn-amazon-book-1-32.pth.tar
# [TEST]
# {'precision': array([0.00012823]), 'recall': array([0.00023327]), 'ndcg': array([0.00019871]), 'hr': array([1.89973214e-05]), 'convergence_speed': 0.0, 'variance': 0.0}
# EPOCH[1/10] loss0.689-|Sample:11.17|
# EPOCH[2/10] loss0.680-|Sample:11.19|
# EPOCH[3/10] loss0.635-|Sample:11.11|
# EPOCH[4/10] loss0.547-|Sample:10.64|
# EPOCH[5/10] loss0.419-|Sample:10.73|
# EPOCH[6/10] loss0.296-|Sample:11.15|
# EPOCH[7/10] loss0.217-|Sample:11.22|
# EPOCH[8/10] loss0.170-|Sample:10.94|
# EPOCH[9/10] loss0.140-|Sample:11.04|
# EPOCH[10/10] loss0.118-|Sample:11.21|

# %%
# !tensorboard --logdir=runs
# Out:
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.11.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
